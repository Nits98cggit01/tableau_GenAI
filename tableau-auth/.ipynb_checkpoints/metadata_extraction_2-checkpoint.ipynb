# %%
import pandas as pd
import os
import json

# %%
root_path = r'C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal'
print(root_path)
# Out:
# C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal

# %%
sitename = '890Portal'

# %%
def create_view_metadata(sitename, root_path):
    views_csv = os.path.join(root_path,f'{sitename}_Views.csv')
    workbooks_csv = os.path.join(root_path,f'{sitename}_Workbooks.csv')
    metadata_csv = os.path.join(root_path,f'{sitename}_View_Metadata.csv')
    
    print(f'View : {views_csv} ; Workbook : {workbooks_csv}')
    
    # Load the Views CSV
    views_df = pd.read_csv(views_csv)
    workbooks_df = pd.read_csv(workbooks_csv)
    
    # Filter Views where sheetType is 'view' and drop rows with NaN values in critical columns
    newdf = views_df[views_df['sheetType'] == 'view']
#     print(f'Check newdf : {newdf}')
    filtered_views = views_df[views_df['sheetType'] == 'view'].dropna(subset=['name', 'workbook_name'])
#     print(f'Filtered view name : {filtered_views["name"]}')
#     print(f'Filtered workbook_name name : {filtered_views["workbook_name"]}')
#     print(f'Filtered views : {filtered_views}')
    
    # Initialize the metadata dataframe
    metadata_df = pd.DataFrame()
    metadata_df['View name'] = filtered_views["name"]
    metadata_df['Workbook name'] = filtered_views["workbook_name"]
    metadata_df['Site name'] = [sitename] * len(filtered_views)
    metadata_df['View alias'] = filtered_views["viewUrlName"]
    
    filtered_views['Workbook url'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[0])
    metadata_df['Workbook url'] = filtered_views['Workbook url'].values
    
    
    # Extract Project name from Workbooks CSV
    project_names = []
    for workbook_name in filtered_views['workbook_name']:
        project_json = workbooks_df[workbooks_df['name'] == workbook_name]['project'].values
        if len(project_json) > 0:
            project_dict = json.loads(project_json[0].replace("'", "\""))  # Ensure correct JSON format
            project_names.append(project_dict['name'])
        else:
            project_names.append('')  # Handle cases where there is no matching workbook name
    
    metadata_df['Project name'] = project_names
    
    print(f'Metadata df : {metadata_df}')
    
    column_names = []
    for view_name, view_alias, project_name, workbook_url in zip(metadata_df['View name'], metadata_df['View alias'] ,metadata_df['Project name'], metadata_df['Workbook url']):
        if pd.notna(view_name) and pd.notna(project_name) and pd.notna(workbook_url):
            file_path = os.path.join(root_path, project_name, workbook_url, f'{view_name}.csv')
#             print(f'Trying to read file: {file_path}')
            if os.path.exists(file_path):
                try:
                    view_data_df = pd.read_csv(file_path)
#                     print(f'Columns in {file_path}: {view_data_df.columns.tolist()}')
                    columns = [col for col in view_data_df.columns if col != 'Unnamed: 0']
                    column_names.append(', '.join(columns))
#                     column_names.append(', '.join(view_data_df.columns))
                except Exception as e:
                    print(f'Error reading {file_path}: {e}')
                    column_names.append('')  # Handle cases where the file cannot be read
            else:
                alias_file_path = os.path.join(root_path, project_name, workbook_url, f'{view_alias}.csv')
                print(f'The alias found for the file : {alias_file_path}')
                if os.path.exists(alias_file_path):
                    try:
                        view_data_df = pd.read_csv(alias_file_path)
                        columns = [col for col in view_data_df.columns if col != 'Unnamed: 0']
                        column_names.append(', '.join(columns))
#                         column_names.append(', '.join(view_data_df.columns))
                    except Exception as e:
                        print(f'Error reading {alias_file_path}: {e}')
                        column_names.append('')  # Handle cases where the file cannot be read
                else:
                    print(f'Files do not exist: {file_path} and {alias_file_path}')
                    column_names.append('')  # Handle cases where neither file exists
                    
        else:
            print(f'Invalid data for view: {view_name}, project: {project_name}, workbook: {workbook_name}')
            column_names.append('')  # Handle cases with NaN values
    
    metadata_df['Column name'] = column_names
    
    print(f'Metadata df : {metadata_df}')
    metadata_df.to_csv(metadata_csv, index=False)

# %%
create_view_metadata(sitename, root_path)
# Out:
# View : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\890Portal_Views.csv ; Workbook : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\890Portal_Workbooks.csv
# Metadata df :                                View name          Workbook name  Site name  \
# 8         Cycle Times on Insurance Claim  Consolidated Cookbook  890Portal
# 9        Rural/Urban Distribution (2019)  Consolidated Cookbook  890Portal
# 10        Promoters vs Detractors (2019)  Consolidated Cookbook  890Portal
# 11                 Y-o-Y CSAT Comparison  Consolidated Cookbook  890Portal
# 12                  Y-o-Y NPS Comparison  Consolidated Cookbook  890Portal
# 14                      Ratio Comparison  Consolidated Cookbook  890Portal
# 15                        Premium Earned  Consolidated Cookbook  890Portal
# 16                     Investment Income  Consolidated Cookbook  890Portal
# 17                        Operating Cost  Consolidated Cookbook  890Portal
# 18                           Claims Loss  Consolidated Cookbook  890Portal
# 19                            Fee Income  Consolidated Cookbook  890Portal
# 20                         Capital Gains  Consolidated Cookbook  890Portal
# 21                         Total Revenue  Consolidated Cookbook  890Portal
# 80                          GHG Emission           GHG Emission  890Portal
# 93                               Sheet 1      Snowflake_Test_Wb  890Portal
# 94                               Sheet 1    Electric_Vehicle_Wb  890Portal
# 96                               Sheet 1             Emissions   890Portal
# 97                               Sheet 1          Flow_Workbook  890Portal
# 100            Department wise Positions  Recruitment Dashboard  890Portal
# 101  Department wise Positions - Legends  Recruitment Dashboard  890Portal
# 102             Job Posting Trend - Open  Recruitment Dashboard  890Portal
# 103           Job Posting Trend - Filled  Recruitment Dashboard  890Portal
# 104          Application Received Source  Recruitment Dashboard  890Portal
# 105              Recruiting Funnel 3 (3)  Recruitment Dashboard  890Portal
# 106                  Reqs vs  Applicants  Recruitment Dashboard  890Portal
# 107                           Total Reqs  Recruitment Dashboard  890Portal
# 108                    Total Reqs Filled  Recruitment Dashboard  890Portal
# 109                      Total Reqs Open  Recruitment Dashboard  890Portal
# 110                 Total Reqs Cancelled  Recruitment Dashboard  890Portal
# 111                 Average # Applicants  Recruitment Dashboard  890Portal
# 112                         Time to hire  Recruitment Dashboard  890Portal
# 113                         Time to fill  Recruitment Dashboard  890Portal
# 114                           1Recruiter  Recruitment Dashboard  890Portal
# 115    1Sankey Chart Recruiter to Status  Recruitment Dashboard  890Portal
# 116                              1Status  Recruitment Dashboard  890Portal
# 117            Experience wise Positions  Recruitment Dashboard  890Portal
# 118                          Gender icon  Recruitment Dashboard  890Portal
# 119                     Recruitment Type  Recruitment Dashboard  890Portal
#
#                           View alias          Workbook url  \
# 8         CycleTimesonInsuranceClaim  ConsolidatedCookbook
# 9         RuralUrbanDistribution2019  ConsolidatedCookbook
# 10         PromotersvsDetractors2019  ConsolidatedCookbook
# 11               Y-o-YCSATComparison  ConsolidatedCookbook
# 12                Y-o-YNPSComparison  ConsolidatedCookbook
# 14                   RatioComparison  ConsolidatedCookbook
# 15                     PremiumEarned  ConsolidatedCookbook
# 16                  InvestmentIncome  ConsolidatedCookbook
# 17                     OperatingCost  ConsolidatedCookbook
# 18                        ClaimsLoss  ConsolidatedCookbook
# 19                         FeeIncome  ConsolidatedCookbook
# 20                      CapitalGains  ConsolidatedCookbook
# 21                      TotalRevenue  ConsolidatedCookbook
# 80                       GHGEmission           GHGEmission
# 93                            Sheet1     Snowflake_Test_Wb
# 94                            Sheet1   Electric_Vehicle_Wb
# 96                            Sheet1             Emissions
# 97                            Sheet1         Flow_Workbook
# 100          DepartmentwisePositions  RecruitmentDashboard
# 101  DepartmentwisePositions-Legends  RecruitmentDashboard
# 102             JobPostingTrend-Open  RecruitmentDashboard
# 103           JobPostingTrend-Filled  RecruitmentDashboard
# 104        ApplicationReceivedSource  RecruitmentDashboard
# 105               RecruitingFunnel33  RecruitmentDashboard
# 106                 ReqsvsApplicants  RecruitmentDashboard
# 107                        TotalReqs  RecruitmentDashboard
# 108                  TotalReqsFilled  RecruitmentDashboard
# 109                    TotalReqsOpen  RecruitmentDashboard
# 110               TotalReqsCancelled  RecruitmentDashboard
# 111                AverageApplicants  RecruitmentDashboard
# 112                       Timetohire  RecruitmentDashboard
# 113                       Timetofill  RecruitmentDashboard
# 114                       1Recruiter  RecruitmentDashboard
# 115    1SankeyChartRecruitertoStatus  RecruitmentDashboard
# 116                          1Status  RecruitmentDashboard
# 117          ExperiencewisePositions  RecruitmentDashboard
# 118                       Gendericon  RecruitmentDashboard
# 119                  RecruitmentType  RecruitmentDashboard
#
#                         Project name
# 8                            Default
# 9                            Default
# 10                           Default
# 11                           Default
# 12                           Default
# 14                           Default
# 15                           Default
# 16                           Default
# 17                           Default
# 18                           Default
# 19                           Default
# 20                           Default
# 21                           Default
# 80                           Default
# 93   CTMT Accelerator Sample Content
# 94   CTMT Accelerator Sample Content
# 96                  CTMT_Sub_Project
# 97   CTMT Accelerator Sample Content
# 100                          Default
# 101                          Default
# 102                          Default
# 103                          Default
# 104                          Default
# 105                          Default
# 106                          Default
# 107                          Default
# 108                          Default
# 109                          Default
# 110                          Default
# 111                          Default
# 112                          Default
# 113                          Default
# 114                          Default
# 115                          Default
# 116                          Default
# 117                          Default
# 118                          Default
# 119                          Default
# The alias found for the file : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Default\ConsolidatedCookbook\RuralUrbanDistribution2019.csv
# Metadata df :                                View name          Workbook name  Site name  \
# 8         Cycle Times on Insurance Claim  Consolidated Cookbook  890Portal
# 9        Rural/Urban Distribution (2019)  Consolidated Cookbook  890Portal
# 10        Promoters vs Detractors (2019)  Consolidated Cookbook  890Portal
# 11                 Y-o-Y CSAT Comparison  Consolidated Cookbook  890Portal
# 12                  Y-o-Y NPS Comparison  Consolidated Cookbook  890Portal
# 14                      Ratio Comparison  Consolidated Cookbook  890Portal
# 15                        Premium Earned  Consolidated Cookbook  890Portal
# 16                     Investment Income  Consolidated Cookbook  890Portal
# 17                        Operating Cost  Consolidated Cookbook  890Portal
# 18                           Claims Loss  Consolidated Cookbook  890Portal
# 19                            Fee Income  Consolidated Cookbook  890Portal
# 20                         Capital Gains  Consolidated Cookbook  890Portal
# 21                         Total Revenue  Consolidated Cookbook  890Portal
# 80                          GHG Emission           GHG Emission  890Portal
# 93                               Sheet 1      Snowflake_Test_Wb  890Portal
# 94                               Sheet 1    Electric_Vehicle_Wb  890Portal
# 96                               Sheet 1             Emissions   890Portal
# 97                               Sheet 1          Flow_Workbook  890Portal
# 100            Department wise Positions  Recruitment Dashboard  890Portal
# 101  Department wise Positions - Legends  Recruitment Dashboard  890Portal
# 102             Job Posting Trend - Open  Recruitment Dashboard  890Portal
# 103           Job Posting Trend - Filled  Recruitment Dashboard  890Portal
# 104          Application Received Source  Recruitment Dashboard  890Portal
# 105              Recruiting Funnel 3 (3)  Recruitment Dashboard  890Portal
# 106                  Reqs vs  Applicants  Recruitment Dashboard  890Portal
# 107                           Total Reqs  Recruitment Dashboard  890Portal
# 108                    Total Reqs Filled  Recruitment Dashboard  890Portal
# 109                      Total Reqs Open  Recruitment Dashboard  890Portal
# 110                 Total Reqs Cancelled  Recruitment Dashboard  890Portal
# 111                 Average # Applicants  Recruitment Dashboard  890Portal
# 112                         Time to hire  Recruitment Dashboard  890Portal
# 113                         Time to fill  Recruitment Dashboard  890Portal
# 114                           1Recruiter  Recruitment Dashboard  890Portal
# 115    1Sankey Chart Recruiter to Status  Recruitment Dashboard  890Portal
# 116                              1Status  Recruitment Dashboard  890Portal
# 117            Experience wise Positions  Recruitment Dashboard  890Portal
# 118                          Gender icon  Recruitment Dashboard  890Portal
# 119                     Recruitment Type  Recruitment Dashboard  890Portal
#
#                           View alias          Workbook url  \
# 8         CycleTimesonInsuranceClaim  ConsolidatedCookbook
# 9         RuralUrbanDistribution2019  ConsolidatedCookbook
# 10         PromotersvsDetractors2019  ConsolidatedCookbook
# 11               Y-o-YCSATComparison  ConsolidatedCookbook
# 12                Y-o-YNPSComparison  ConsolidatedCookbook
# 14                   RatioComparison  ConsolidatedCookbook
# 15                     PremiumEarned  ConsolidatedCookbook
# 16                  InvestmentIncome  ConsolidatedCookbook
# 17                     OperatingCost  ConsolidatedCookbook
# 18                        ClaimsLoss  ConsolidatedCookbook
# 19                         FeeIncome  ConsolidatedCookbook
# 20                      CapitalGains  ConsolidatedCookbook
# 21                      TotalRevenue  ConsolidatedCookbook
# 80                       GHGEmission           GHGEmission
# 93                            Sheet1     Snowflake_Test_Wb
# 94                            Sheet1   Electric_Vehicle_Wb
# 96                            Sheet1             Emissions
# 97                            Sheet1         Flow_Workbook
# 100          DepartmentwisePositions  RecruitmentDashboard
# 101  DepartmentwisePositions-Legends  RecruitmentDashboard
# 102             JobPostingTrend-Open  RecruitmentDashboard
# 103           JobPostingTrend-Filled  RecruitmentDashboard
# 104        ApplicationReceivedSource  RecruitmentDashboard
# 105               RecruitingFunnel33  RecruitmentDashboard
# 106                 ReqsvsApplicants  RecruitmentDashboard
# 107                        TotalReqs  RecruitmentDashboard
# 108                  TotalReqsFilled  RecruitmentDashboard
# 109                    TotalReqsOpen  RecruitmentDashboard
# 110               TotalReqsCancelled  RecruitmentDashboard
# 111                AverageApplicants  RecruitmentDashboard
# 112                       Timetohire  RecruitmentDashboard
# 113                       Timetofill  RecruitmentDashboard
# 114                       1Recruiter  RecruitmentDashboard
# 115    1SankeyChartRecruitertoStatus  RecruitmentDashboard
# 116                          1Status  RecruitmentDashboard
# 117          ExperiencewisePositions  RecruitmentDashboard
# 118                       Gendericon  RecruitmentDashboard
# 119                  RecruitmentType  RecruitmentDashboard
#
#                         Project name  \
# 8                            Default
# 9                            Default
# 10                           Default
# 11                           Default
# 12                           Default
# 14                           Default
# 15                           Default
# 16                           Default
# 17                           Default
# 18                           Default
# 19                           Default
# 20                           Default
# 21                           Default
# 80                           Default
# 93   CTMT Accelerator Sample Content
# 94   CTMT Accelerator Sample Content
# 96                  CTMT_Sub_Project
# 97   CTMT Accelerator Sample Content
# 100                          Default
# 101                          Default
# 102                          Default
# 103                          Default
# 104                          Default
# 105                          Default
# 106                          Default
# 107                          Default
# 108                          Default
# 109                          Default
# 110                          Default
# 111                          Default
# 112                          Default
# 113                          Default
# 114                          Default
# 115                          Default
# 116                          Default
# 117                          Default
# 118                          Default
# 119                          Default
#
#                                            Column name
# 8                                       ID, Cycle Time
# 9                      Urbanicity, Count of Urbanicity
# 10     Detractor/Promoter, Count of Detractor/Promoter
# 11                   Year, CSAT (Industry), CSAT (Org)
# 12                     Year, NPS (Industry), NPS (Org)
# 14     Year, Combined Ratio, Expense Ratio, Loss Ratio
# 15                                Year, Earned Premium
# 16                         Year, Net Investment Income
# 17                                Year, Operating Cost
# 18                                   Year, Claims Loss
# 19                                    Year, Fee Income
# 20                     Year, Net Realized Capital Gain
# 21                                Year, Total Revenues
# 80                               Country, Year, Meaure
# 93                    Travelcategory, Traveltype, Cost
# 94                             City, 2020 Census Tract
# 96                             City, 2020 Census Tract
# 97   Measure Names, Sourcename, Traveltype, Measure...
# 100                         Department, # of Positions
# 101                  Department, # of Positions, Index
# 102           Month of Job Posted Date, # of Positions
# 103           Month of Job Filled Date, # of Positions
# 104  Source , Count of Appl Id, % of Total Count of...
# 105  Measure Names, Stage, Max. 1 Tootltip (, Max. ...
# 106  Skills, Avg. # of Applicants, Avg. TTF, Count ...
# 107                                 Count of # of Reqs
# 108                                  Count Reqs Filled
# 109                                    Count Reqs Open
# 110                               Count Reqs Cancelled
# 111                                 Average Applicants
# 112                                  Avg. Time To Hire
# 113                         Avg. fill_time_calculation
# 114                  Recruiter (Viz), % of Total VizId
# 115  Paded, Recruiter (Viz), Status (Viz), Curve, J...
# 116  Status (Viz), Recruiter - Selected, % of Total...
# 117               Experience, Count of # of Applicants
# 118  Gender1, Measure Names, % of Total Count of Jo...
# 119        Recruitment Type, Distinct count of Job Id1

# %%
def create_view_metadata1(sitename, root_path):
    views_csv = os.path.join(root_path, f'{sitename}_Views.csv')
    workbooks_csv = os.path.join(root_path, f'{sitename}_Workbooks.csv')
    metadata_csv = os.path.join(root_path, f'{sitename}_View_Metadata.csv')
    
    print(f'View : {views_csv} ; Workbook : {workbooks_csv}')
    
    # Load the Views CSV
    views_df = pd.read_csv(views_csv)
    workbooks_df = pd.read_csv(workbooks_csv)
    
    # Filter Views where sheetType is 'view'
    filtered_views = views_df[views_df['sheetType'] == 'view']
    
    # Extract workbook_name and view_name from contentUrl
    filtered_views['workbook_url'] = filtered_views["workbook_name"]
    filtered_views['workbook_name'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[0])
    filtered_views['view_name'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[-1])
    
    # Drop rows with NaN values in critical columns
    filtered_views = filtered_views.dropna(subset=['view_name', 'workbook_name'])
    
    print(f'Filtered view names: {filtered_views["view_name"].tolist()}')
    print(f'Filtered workbook names: {filtered_views["workbook_name"].tolist()}')
    print(f'Filtered workbook url: {filtered_views["workbook_url"].tolist()}')
    
    
    # Initialize the metadata dataframe
    metadata_df = pd.DataFrame()
    metadata_df['Site name'] = [sitename] * len(filtered_views)
    metadata_df['View name'] = filtered_views['view_name'].values
    metadata_df['Workbook name'] = filtered_views['workbook_name'].values
    metadata_df['Workbook url'] = filtered_views['workbook_url']
    
    # Extract Project name from Workbooks CSV
    project_names = []
    for workbook_name in filtered_views['workbook_name']:
        project_json = workbooks_df[workbooks_df['name'] == workbook_name]['project'].values
        if len(project_json) > 0:
            project_dict = json.loads(project_json[0].replace("'", "\""))  # Ensure correct JSON format
            project_names.append(project_dict['name'])
        else:
            project_names.append('')  # Handle cases where there is no matching workbook name
    
    metadata_df['Project name'] = project_names
    
    # Extract Column names by traversing the file structure
    column_names = []
    for view_name, project_name, workbook_name in zip(metadata_df['View name'], metadata_df['Project name'], metadata_df['Workbook url']):
        if pd.notna(view_name) and pd.notna(project_name) and pd.notna(workbook_name):
            file_path = os.path.join(root_path, project_name, workbook_name, f'{view_name}.csv')
            print(f'Trying to read file: {file_path}')
            if os.path.exists(file_path):
                try:
                    view_data_df = pd.read_csv(file_path)
                    print(f'Columns in {file_path}: {view_data_df.columns.tolist()}')
                    column_names.append(', '.join(view_data_df.columns))
                except Exception as e:
                    print(f'Error reading {file_path}: {e}')
                    column_names.append('')  # Handle cases where the file cannot be read
            else:
                print(f'File does not exist: {file_path}')
                column_names.append('')  # Handle cases where the file does not exist
        else:
            print(f'Invalid data for view: {view_name}, project: {project_name}, workbook: {workbook_name}')
            column_names.append('')  # Handle cases with NaN values
    
    metadata_df['Column name'] = column_names
    
    print(f'Metadata dataframe:\n{metadata_df}')

# %%
create_view_metadata1(sitename, root_path)
# Out:
# View : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\890Portal_Views.csv ; Workbook : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\890Portal_Workbooks.csv
# Filtered view names: ['CycleTimesonInsuranceClaim', 'RuralUrbanDistribution2019', 'PromotersvsDetractors2019', 'Y-o-YCSATComparison', 'Y-o-YNPSComparison', 'RatioComparison', 'PremiumEarned', 'InvestmentIncome', 'OperatingCost', 'ClaimsLoss', 'FeeIncome', 'CapitalGains', 'TotalRevenue', 'GHGEmission', 'Sheet1', 'Sheet1', 'Sheet1', 'Sheet1', 'DepartmentwisePositions', 'DepartmentwisePositions-Legends', 'JobPostingTrend-Open', 'JobPostingTrend-Filled', 'ApplicationReceivedSource', 'RecruitingFunnel33', 'ReqsvsApplicants', 'TotalReqs', 'TotalReqsFilled', 'TotalReqsOpen', 'TotalReqsCancelled', 'AverageApplicants', 'Timetohire', 'Timetofill', '1Recruiter', '1SankeyChartRecruitertoStatus', '1Status', 'ExperiencewisePositions', 'Gendericon', 'RecruitmentType']
# Filtered workbook names: ['ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'ConsolidatedCookbook', 'GHGEmission', 'Snowflake_Test_Wb', 'Electric_Vehicle_Wb', 'Emissions', 'Flow_Workbook', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard', 'RecruitmentDashboard']
# Filtered workbook url: ['Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'Consolidated Cookbook', 'GHG Emission', 'Snowflake_Test_Wb', 'Electric_Vehicle_Wb', 'Emissions ', 'Flow_Workbook', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard', 'Recruitment Dashboard']
# Invalid data for view: CycleTimesonInsuranceClaim, project: , workbook: nan
# Invalid data for view: RuralUrbanDistribution2019, project: , workbook: nan
# Invalid data for view: PromotersvsDetractors2019, project: , workbook: nan
# Invalid data for view: Y-o-YCSATComparison, project: , workbook: nan
# Invalid data for view: Y-o-YNPSComparison, project: , workbook: nan
# Invalid data for view: RatioComparison, project: , workbook: nan
# Invalid data for view: PremiumEarned, project: , workbook: nan
# Invalid data for view: InvestmentIncome, project: , workbook: nan
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\OperatingCost.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\OperatingCost.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\ClaimsLoss.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\ClaimsLoss.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\FeeIncome.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\FeeIncome.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\CapitalGains.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\CapitalGains.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\TotalRevenue.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\TotalRevenue.csv
# Invalid data for view: GHGEmission, project: , workbook: nan
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\CTMT Accelerator Sample Content\Consolidated Cookbook\Sheet1.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\CTMT Accelerator Sample Content\Consolidated Cookbook\Sheet1.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\CTMT Accelerator Sample Content\Consolidated Cookbook\Sheet1.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\CTMT Accelerator Sample Content\Consolidated Cookbook\Sheet1.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\Sheet1.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\Sheet1.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\CTMT Accelerator Sample Content\Consolidated Cookbook\Sheet1.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\CTMT Accelerator Sample Content\Consolidated Cookbook\Sheet1.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\DepartmentwisePositions.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\DepartmentwisePositions.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\DepartmentwisePositions-Legends.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\DepartmentwisePositions-Legends.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\JobPostingTrend-Open.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\JobPostingTrend-Open.csv
# Trying to read file: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\JobPostingTrend-Filled.csv
# File does not exist: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Consolidated Cookbook\JobPostingTrend-Filled.csv
# Invalid data for view: ApplicationReceivedSource, project: , workbook: nan
# Invalid data for view: RecruitingFunnel33, project: , workbook: nan
# Invalid data for view: ReqsvsApplicants, project: , workbook: nan
# Invalid data for view: TotalReqs, project: , workbook: nan
# Invalid data for view: TotalReqsFilled, project: , workbook: nan
# Invalid data for view: TotalReqsOpen, project: , workbook: nan
# Invalid data for view: TotalReqsCancelled, project: , workbook: nan
# Invalid data for view: AverageApplicants, project: , workbook: nan
# Invalid data for view: Timetohire, project: , workbook: nan
# Invalid data for view: Timetofill, project: , workbook: nan
# Invalid data for view: 1Recruiter, project: , workbook: nan
# Invalid data for view: 1SankeyChartRecruitertoStatus, project: , workbook: nan
# Invalid data for view: 1Status, project: , workbook: nan
# Invalid data for view: ExperiencewisePositions, project: , workbook: nan
# Invalid data for view: Gendericon, project: , workbook: nan
# Invalid data for view: RecruitmentType, project: , workbook: nan
# Metadata dataframe:
#     Site name                        View name         Workbook name  \
# 0   890Portal       CycleTimesonInsuranceClaim  ConsolidatedCookbook
# 1   890Portal       RuralUrbanDistribution2019  ConsolidatedCookbook
# 2   890Portal        PromotersvsDetractors2019  ConsolidatedCookbook
# 3   890Portal              Y-o-YCSATComparison  ConsolidatedCookbook
# 4   890Portal               Y-o-YNPSComparison  ConsolidatedCookbook
# 5   890Portal                  RatioComparison  ConsolidatedCookbook
# 6   890Portal                    PremiumEarned  ConsolidatedCookbook
# 7   890Portal                 InvestmentIncome  ConsolidatedCookbook
# 8   890Portal                    OperatingCost  ConsolidatedCookbook
# 9   890Portal                       ClaimsLoss  ConsolidatedCookbook
# 10  890Portal                        FeeIncome  ConsolidatedCookbook
# 11  890Portal                     CapitalGains  ConsolidatedCookbook
# 12  890Portal                     TotalRevenue  ConsolidatedCookbook
# 13  890Portal                      GHGEmission           GHGEmission
# 14  890Portal                           Sheet1     Snowflake_Test_Wb
# 15  890Portal                           Sheet1   Electric_Vehicle_Wb
# 16  890Portal                           Sheet1             Emissions
# 17  890Portal                           Sheet1         Flow_Workbook
# 18  890Portal          DepartmentwisePositions  RecruitmentDashboard
# 19  890Portal  DepartmentwisePositions-Legends  RecruitmentDashboard
# 20  890Portal             JobPostingTrend-Open  RecruitmentDashboard
# 21  890Portal           JobPostingTrend-Filled  RecruitmentDashboard
# 22  890Portal        ApplicationReceivedSource  RecruitmentDashboard
# 23  890Portal               RecruitingFunnel33  RecruitmentDashboard
# 24  890Portal                 ReqsvsApplicants  RecruitmentDashboard
# 25  890Portal                        TotalReqs  RecruitmentDashboard
# 26  890Portal                  TotalReqsFilled  RecruitmentDashboard
# 27  890Portal                    TotalReqsOpen  RecruitmentDashboard
# 28  890Portal               TotalReqsCancelled  RecruitmentDashboard
# 29  890Portal                AverageApplicants  RecruitmentDashboard
# 30  890Portal                       Timetohire  RecruitmentDashboard
# 31  890Portal                       Timetofill  RecruitmentDashboard
# 32  890Portal                       1Recruiter  RecruitmentDashboard
# 33  890Portal    1SankeyChartRecruitertoStatus  RecruitmentDashboard
# 34  890Portal                          1Status  RecruitmentDashboard
# 35  890Portal          ExperiencewisePositions  RecruitmentDashboard
# 36  890Portal                       Gendericon  RecruitmentDashboard
# 37  890Portal                  RecruitmentType  RecruitmentDashboard
#
#              Workbook url                     Project name Column name
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8   Consolidated Cookbook
# 9   Consolidated Cookbook
# 10  Consolidated Cookbook
# 11  Consolidated Cookbook
# 12  Consolidated Cookbook
# 13                    NaN
# 14  Consolidated Cookbook  CTMT Accelerator Sample Content
# 15  Consolidated Cookbook  CTMT Accelerator Sample Content
# 16  Consolidated Cookbook
# 17  Consolidated Cookbook  CTMT Accelerator Sample Content
# 18  Consolidated Cookbook
# 19  Consolidated Cookbook
# 20  Consolidated Cookbook
# 21  Consolidated Cookbook
# 22                    NaN
# 23                    NaN
# 24                    NaN
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28                    NaN
# 29                    NaN
# 30                    NaN
# 31                    NaN
# 32                    NaN
# 33                    NaN
# 34                    NaN
# 35                    NaN
# 36                    NaN
# 37                    NaN
# C:\Users\NITINS\AppData\Local\Temp\ipykernel_14944\3470226222.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_views['workbook_url'] = filtered_views["workbook_name"]
# C:\Users\NITINS\AppData\Local\Temp\ipykernel_14944\3470226222.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_views['workbook_name'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[0])
# C:\Users\NITINS\AppData\Local\Temp\ipykernel_14944\3470226222.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_views['view_name'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[-1])
