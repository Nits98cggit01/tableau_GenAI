# %%
import pandas as pd
import os
import re
import json
from tableau_api_lib import TableauServerConnection
from tableau_api_lib.utils import querying, flatten_dict_column
from typing import List

# %%
root_path = r'C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal'
print(root_path)
# Out:
# C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal

# %%
sitename = '890Portal'

# %%
config = {
    "tableau-server" : {
        "server" : 'http://10.100.252.218/',
        "api_version" : "3.19",
        "personal_access_token_name" : "rest_token",
        "personal_access_token_secret" : "zL6zdQRgS9WQYH24aGR4JQ==:7yDTI0BCA6XlNxOm24YDN6S3B6673Nyn",
        "site_name" : "890Portal",
        "site_url" : "890Portal"
    }
}

# %%
conn = TableauServerConnection(config_json=config,env="tableau-server")

# %%
response = conn.sign_in()

# %%
response
# Out:
# <Response [200]>

# %%
def create_view_metadata(sitename, root_path):
    views_csv = os.path.join(root_path, f'{sitename}_Views.csv')
    workbooks_csv = os.path.join(root_path, f'{sitename}_Workbooks.csv')
    metadata_csv = os.path.join(root_path, f'{sitename}_View_Metadata.csv')
    unextracted = []
    extracted = []
    print(f'View : {views_csv} ; Workbook : {workbooks_csv}')

    # Load the Views CSV
    views_df = pd.read_csv(views_csv)
    workbooks_df = pd.read_csv(workbooks_csv)

    # Create a directory for saving images if it doesn't exist
    os.makedirs(os.path.join(root_path, 'Dashboard_images'), exist_ok=True)
    
    print(f'Processing view:')
    filtered_views = views_df[views_df['sheetType'] == 'view'].dropna(subset=['name', 'workbook_name'])
    metadata_df = pd.DataFrame()
    metadata_df['View name'] = filtered_views["name"]
    metadata_df['Workbook name'] = filtered_views["workbook_name"]
    metadata_df['Site name'] = [sitename] * len(filtered_views)
    metadata_df['View alias'] = filtered_views["viewUrlName"]

    filtered_views['Workbook url'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[0])
    metadata_df['Workbook url'] = filtered_views['Workbook url'].values

    # Extract Project name from Workbooks CSV
    project_names = []
    for workbook_name in filtered_views['workbook_name']:
        project_json = workbooks_df[workbooks_df['name'] == workbook_name]['project'].values
        if len(project_json) > 0:
            project_dict = json.loads(project_json[0].replace("'", "\""))  # Ensure correct JSON format
            project_names.append(project_dict['name'])
        else:
            project_names.append('')  # Handle cases where there is no matching workbook name

    metadata_df['Project name'] = project_names

    column_names = []
    for view_name, view_alias, project_name, workbook_url in zip(metadata_df['View name'], metadata_df['View alias'], metadata_df['Project name'], metadata_df['Workbook url']):
        if pd.notna(view_name) and pd.notna(project_name) and pd.notna(workbook_url):
            file_path = os.path.join(root_path, project_name, workbook_url, f'{view_name}.csv')
            if os.path.exists(file_path):
                try:
                    view_data_df = pd.read_csv(file_path)
                    columns = [col for col in view_data_df.columns if col != 'Unnamed: 0']
                    column_names.append(', '.join(columns))
                except Exception as e:
                    print(f'Error reading {file_path}: {e}')
                    column_names.append('')  # Handle cases where the file cannot be read
            else:
                alias_file_path = os.path.join(root_path, project_name, workbook_url, f'{view_alias}.csv')
                print(f'The alias found for the file : {alias_file_path}')
                if os.path.exists(alias_file_path):
                    try:
                        view_data_df = pd.read_csv(alias_file_path)
                        columns = [col for col in view_data_df.columns if col != 'Unnamed: 0']
                        column_names.append(', '.join(columns))
                    except Exception as e:
                        print(f'Error reading {alias_file_path}: {e}')
                        column_names.append('')  # Handle cases where the file cannot be read
                else:
                    print(f'Files do not exist: {file_path} and {alias_file_path}')
                    column_names.append('')  # Handle cases where neither file exists
        else:
            print(f'Invalid data for view: {view_name}, project: {project_name}, workbook: {workbook_url}')
            column_names.append('')  # Handle cases with NaN values

    metadata_df['Column name'] = column_names

    print(f'Metadata df : {metadata_df}')
    metadata_df.to_csv(metadata_csv, index=False)
        
    # Process dashboards
    print(f'Processing dashboard:')
    portal_dashdf = views_df[views_df['sheetType'] == 'dashboard']
    portal_dashdf = portal_dashdf[['name', 'id', 'contentUrl', 'sheetType', 'viewUrlName', 'workbook_name', 'workbook_id']]
    portal_dashdf.to_csv(os.path.join(root_path, '890Portal_Dashboards.csv'))

    for index, row in portal_dashdf.iterrows():
        dashid = row['id']
        print(f"Dashid : {dashid}")
        name = row['name']
        view_url_name = row['viewUrlName']
        workbook_name = row['workbook_name']

        # Check for special characters in the 'name' and replace the filename if necessary
        if re.search(r'[\\/]', name):
            filename = f'{workbook_name}_{view_url_name}' + '.png'
        else:
            filename = f'{workbook_name}_{name}' + '.png'

        print(f"Trying to extract the image for {dashid}")

        try:
            view_png = conn.query_view_image(view_id=dashid)

            # Save the image with the appropriate filename
            with open(os.path.join(root_path, 'Dashboard_images', filename), 'wb') as v:
                v.write(view_png.content)
            print(f'The Dashboard image for {filename} is extracted')
            extracted.append(filename)
        except Exception as e:
            print(f'The Dashboard image for {filename} could not be extracted: {e}')
            unextracted.append(filename)

    print(f'The dashboards for which the image could not be extracted: {unextracted}')
    print(f'The dashboards for which the image that are extracted: {extracted}')

# %%
create_view_metadata(sitename, root_path)
# Out:
# View : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\890Portal_Views.csv ; Workbook : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\890Portal_Workbooks.csv
# Processing view:
# The alias found for the file : C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\report-usecase\tableau\tableau-auth\pat\890Portal\Default\ConsolidatedCookbook\RuralUrbanDistribution2019.csv
# Metadata df :                                View name          Workbook name  Site name  \
# 8         Cycle Times on Insurance Claim  Consolidated Cookbook  890Portal
# 9        Rural/Urban Distribution (2019)  Consolidated Cookbook  890Portal
# 10        Promoters vs Detractors (2019)  Consolidated Cookbook  890Portal
# 11                 Y-o-Y CSAT Comparison  Consolidated Cookbook  890Portal
# 12                  Y-o-Y NPS Comparison  Consolidated Cookbook  890Portal
# 14                      Ratio Comparison  Consolidated Cookbook  890Portal
# 15                        Premium Earned  Consolidated Cookbook  890Portal
# 16                     Investment Income  Consolidated Cookbook  890Portal
# 17                        Operating Cost  Consolidated Cookbook  890Portal
# 18                           Claims Loss  Consolidated Cookbook  890Portal
# 19                            Fee Income  Consolidated Cookbook  890Portal
# 20                         Capital Gains  Consolidated Cookbook  890Portal
# 21                         Total Revenue  Consolidated Cookbook  890Portal
# 80                          GHG Emission           GHG Emission  890Portal
# 93                               Sheet 1      Snowflake_Test_Wb  890Portal
# 94                               Sheet 1    Electric_Vehicle_Wb  890Portal
# 96                               Sheet 1             Emissions   890Portal
# 97                               Sheet 1          Flow_Workbook  890Portal
# 100            Department wise Positions  Recruitment Dashboard  890Portal
# 101  Department wise Positions - Legends  Recruitment Dashboard  890Portal
# 102             Job Posting Trend - Open  Recruitment Dashboard  890Portal
# 103           Job Posting Trend - Filled  Recruitment Dashboard  890Portal
# 104          Application Received Source  Recruitment Dashboard  890Portal
# 105              Recruiting Funnel 3 (3)  Recruitment Dashboard  890Portal
# 106                  Reqs vs  Applicants  Recruitment Dashboard  890Portal
# 107                           Total Reqs  Recruitment Dashboard  890Portal
# 108                    Total Reqs Filled  Recruitment Dashboard  890Portal
# 109                      Total Reqs Open  Recruitment Dashboard  890Portal
# 110                 Total Reqs Cancelled  Recruitment Dashboard  890Portal
# 111                 Average # Applicants  Recruitment Dashboard  890Portal
# 112                         Time to hire  Recruitment Dashboard  890Portal
# 113                         Time to fill  Recruitment Dashboard  890Portal
# 114                           1Recruiter  Recruitment Dashboard  890Portal
# 115    1Sankey Chart Recruiter to Status  Recruitment Dashboard  890Portal
# 116                              1Status  Recruitment Dashboard  890Portal
# 117            Experience wise Positions  Recruitment Dashboard  890Portal
# 118                          Gender icon  Recruitment Dashboard  890Portal
# 119                     Recruitment Type  Recruitment Dashboard  890Portal
#
#                           View alias          Workbook url  \
# 8         CycleTimesonInsuranceClaim  ConsolidatedCookbook
# 9         RuralUrbanDistribution2019  ConsolidatedCookbook
# 10         PromotersvsDetractors2019  ConsolidatedCookbook
# 11               Y-o-YCSATComparison  ConsolidatedCookbook
# 12                Y-o-YNPSComparison  ConsolidatedCookbook
# 14                   RatioComparison  ConsolidatedCookbook
# 15                     PremiumEarned  ConsolidatedCookbook
# 16                  InvestmentIncome  ConsolidatedCookbook
# 17                     OperatingCost  ConsolidatedCookbook
# 18                        ClaimsLoss  ConsolidatedCookbook
# 19                         FeeIncome  ConsolidatedCookbook
# 20                      CapitalGains  ConsolidatedCookbook
# 21                      TotalRevenue  ConsolidatedCookbook
# 80                       GHGEmission           GHGEmission
# 93                            Sheet1     Snowflake_Test_Wb
# 94                            Sheet1   Electric_Vehicle_Wb
# 96                            Sheet1             Emissions
# 97                            Sheet1         Flow_Workbook
# 100          DepartmentwisePositions  RecruitmentDashboard
# 101  DepartmentwisePositions-Legends  RecruitmentDashboard
# 102             JobPostingTrend-Open  RecruitmentDashboard
# 103           JobPostingTrend-Filled  RecruitmentDashboard
# 104        ApplicationReceivedSource  RecruitmentDashboard
# 105               RecruitingFunnel33  RecruitmentDashboard
# 106                 ReqsvsApplicants  RecruitmentDashboard
# 107                        TotalReqs  RecruitmentDashboard
# 108                  TotalReqsFilled  RecruitmentDashboard
# 109                    TotalReqsOpen  RecruitmentDashboard
# 110               TotalReqsCancelled  RecruitmentDashboard
# 111                AverageApplicants  RecruitmentDashboard
# 112                       Timetohire  RecruitmentDashboard
# 113                       Timetofill  RecruitmentDashboard
# 114                       1Recruiter  RecruitmentDashboard
# 115    1SankeyChartRecruitertoStatus  RecruitmentDashboard
# 116                          1Status  RecruitmentDashboard
# 117          ExperiencewisePositions  RecruitmentDashboard
# 118                       Gendericon  RecruitmentDashboard
# 119                  RecruitmentType  RecruitmentDashboard
#
#                         Project name  \
# 8                            Default
# 9                            Default
# 10                           Default
# 11                           Default
# 12                           Default
# 14                           Default
# 15                           Default
# 16                           Default
# 17                           Default
# 18                           Default
# 19                           Default
# 20                           Default
# 21                           Default
# 80                           Default
# 93   CTMT Accelerator Sample Content
# 94   CTMT Accelerator Sample Content
# 96                  CTMT_Sub_Project
# 97   CTMT Accelerator Sample Content
# 100                          Default
# 101                          Default
# 102                          Default
# 103                          Default
# 104                          Default
# 105                          Default
# 106                          Default
# 107                          Default
# 108                          Default
# 109                          Default
# 110                          Default
# 111                          Default
# 112                          Default
# 113                          Default
# 114                          Default
# 115                          Default
# 116                          Default
# 117                          Default
# 118                          Default
# 119                          Default
#
#                                            Column name
# 8                                       ID, Cycle Time
# 9                      Urbanicity, Count of Urbanicity
# 10     Detractor/Promoter, Count of Detractor/Promoter
# 11                   Year, CSAT (Industry), CSAT (Org)
# 12                     Year, NPS (Industry), NPS (Org)
# 14     Year, Combined Ratio, Expense Ratio, Loss Ratio
# 15                                Year, Earned Premium
# 16                         Year, Net Investment Income
# 17                                Year, Operating Cost
# 18                                   Year, Claims Loss
# 19                                    Year, Fee Income
# 20                     Year, Net Realized Capital Gain
# 21                                Year, Total Revenues
# 80                               Country, Year, Meaure
# 93                    Travelcategory, Traveltype, Cost
# 94                             City, 2020 Census Tract
# 96                             City, 2020 Census Tract
# 97   Measure Names, Sourcename, Traveltype, Measure...
# 100                         Department, # of Positions
# 101                  Department, # of Positions, Index
# 102           Month of Job Posted Date, # of Positions
# 103           Month of Job Filled Date, # of Positions
# 104  Source , Count of Appl Id, % of Total Count of...
# 105  Measure Names, Stage, Max. 1 Tootltip (, Max. ...
# 106  Skills, Avg. # of Applicants, Avg. TTF, Count ...
# 107                                 Count of # of Reqs
# 108                                  Count Reqs Filled
# 109                                    Count Reqs Open
# 110                               Count Reqs Cancelled
# 111                                 Average Applicants
# 112                                  Avg. Time To Hire
# 113                         Avg. fill_time_calculation
# 114                  Recruiter (Viz), % of Total VizId
# 115  Paded, Recruiter (Viz), Status (Viz), Curve, J...
# 116  Status (Viz), Recruiter - Selected, % of Total...
# 117               Experience, Count of # of Applicants
# 118  Gender1, Measure Names, % of Total Count of Jo...
# 119        Recruitment Type, Distinct count of Job Id1
# Processing dashboard:
# Dashid : 6047b331-14cc-485b-a6a8-eeebdfd7f03a
# Trying to extract the image for 6047b331-14cc-485b-a6a8-eeebdfd7f03a
# The Dashboard image for CMO_Dashboard-WIP_Reach.png is extracted
# Dashid : c61b802a-8a5d-49fe-a6f9-91eb6e4ceea3
# Trying to extract the image for c61b802a-8a5d-49fe-a6f9-91eb6e4ceea3
# The Dashboard image for CMO_Dashboard-WIP_Promotion Effect.png is extracted
# Dashid : 608163b1-d010-4514-9277-f693d8c64b26
# Trying to extract the image for 608163b1-d010-4514-9277-f693d8c64b26
# The Dashboard image for CMO_Dashboard-WIP_Conversion.png is extracted
# Dashid : 25d485af-bfc4-4451-9fbb-661888b37ff7
# Trying to extract the image for 25d485af-bfc4-4451-9fbb-661888b37ff7
# The Dashboard image for CMO_Dashboard_Dashboard 1.png is extracted
# Dashid : cbcc0b15-9c83-40a6-aea0-6768593ad506
# Trying to extract the image for cbcc0b15-9c83-40a6-aea0-6768593ad506
# The Dashboard image for CMO_Dashboard_Reach.png is extracted
# Dashid : 2d15e4db-ea02-46ea-ae1c-4b23f43cc890
# Trying to extract the image for 2d15e4db-ea02-46ea-ae1c-4b23f43cc890
# The Dashboard image for CMO_Dashboard_Promotion Effect.png is extracted
# Dashid : a31a6cc1-104f-4351-bd1a-df62814990b1
# Trying to extract the image for a31a6cc1-104f-4351-bd1a-df62814990b1
# The Dashboard image for CMO_Dashboard_Conversion.png is extracted
# Dashid : 8cbc3450-ad21-461e-802e-ac82bfac5126
# Trying to extract the image for 8cbc3450-ad21-461e-802e-ac82bfac5126
# The Dashboard image for CMO_Dashboard_Content.png is extracted
# Dashid : 4c29991b-0b11-4243-8a1b-650f52e236d5
# Trying to extract the image for 4c29991b-0b11-4243-8a1b-650f52e236d5
# The Dashboard image for Consolidated Cookbook_Comparison of People Metrics.png is extracted
# Dashid : 2d0e3014-b2e0-4d3c-a07e-a0f2cb3a2b59
# Trying to extract the image for 2d0e3014-b2e0-4d3c-a07e-a0f2cb3a2b59
# The Dashboard image for Consolidated Cookbook_Comparison of Financial Metrics.png is extracted
# Dashid : 1f72d65f-4166-44ae-907f-bb783a1531a1
# Trying to extract the image for 1f72d65f-4166-44ae-907f-bb783a1531a1
# The Dashboard image for Healthcare-Fraud-Detection_Overview.png is extracted
# Dashid : 5111ec49-5d6e-4102-ba0a-4bdd2d4bd101
# Trying to extract the image for 5111ec49-5d6e-4102-ba0a-4bdd2d4bd101
# The Dashboard image for Healthcare-Fraud-Detection_Digital Healthcare Ecosystem.png is extracted
# Dashid : c86451f1-daf8-4fdd-b19b-5b11bf7c036f
# Trying to extract the image for c86451f1-daf8-4fdd-b19b-5b11bf7c036f
# The Dashboard image for Healthcare-Fraud-Detection_Healthcare Insights from Data.png is extracted
# Dashid : a93ce1c5-c0d7-40b3-a24d-415ada65467d
# Trying to extract the image for a93ce1c5-c0d7-40b3-a24d-415ada65467d
# The Dashboard image for Healthcare-Fraud-Detection_Fraud Claims Dashboard.png is extracted
# Dashid : 26144275-48db-425a-871a-cc98451f7269
# Trying to extract the image for 26144275-48db-425a-871a-cc98451f7269
# The Dashboard image for HealthCareFraudulentClaims_Anomaly Detection.png is extracted
# Dashid : f3772e7e-817b-4795-9ae3-dbbf609f3e8a
# Trying to extract the image for f3772e7e-817b-4795-9ae3-dbbf609f3e8a
# The Dashboard image for Loss Control-Towing_Network-Savings-Dashboard.png is extracted
# Dashid : 3809bb07-3690-4c26-bc46-aed8bc6afb65
# Trying to extract the image for 3809bb07-3690-4c26-bc46-aed8bc6afb65
# The Dashboard image for Loss Control-Towing_Exceptions-Dashboard.png is extracted
# Dashid : b43be72e-3b7c-478b-957a-ce51bb4a204b
# Trying to extract the image for b43be72e-3b7c-478b-957a-ce51bb4a204b
# The Dashboard image for Loss Control-Towing_Landing-Page-Dashboard.png is extracted
# Dashid : 1e2e99fd-6a97-4b02-a05b-9d8cc941fec5
# Trying to extract the image for 1e2e99fd-6a97-4b02-a05b-9d8cc941fec5
# The Dashboard image for Workbook for Spanish Insurance v3_Dashboard Great Car Company.png is extracted
# Dashid : 059e85ac-30d3-4ac5-b246-414dda975f6e
# Trying to extract the image for 059e85ac-30d3-4ac5-b246-414dda975f6e
# The Dashboard image for WFH Analytics_Overview.png is extracted
# Dashid : dcede592-e082-4114-9989-a47d6d2ff7bc
# Trying to extract the image for dcede592-e082-4114-9989-a47d6d2ff7bc
# The Dashboard image for WFH Analytics_Detailed Insights.png is extracted
# Dashid : 2e0f9ba3-cc85-4fea-9ccc-f8995f7bc1f7
# Trying to extract the image for 2e0f9ba3-cc85-4fea-9ccc-f8995f7bc1f7
# The Dashboard image for WFH Analytics Draft_Overview.png is extracted
# Dashid : 02cf7bae-8d05-4a4a-b98f-40e63a1cd327
# Trying to extract the image for 02cf7bae-8d05-4a4a-b98f-40e63a1cd327
# The Dashboard image for WFH Analytics Draft_Detailed Insights.png is extracted
# Dashid : c2829716-ea1c-405a-ae83-d679f50797da
# Trying to extract the image for c2829716-ea1c-405a-ae83-d679f50797da
# The Dashboard image for Covid 19 Internal V6_Executive Dashboard.png is extracted
# Dashid : fb2e1d79-9f64-4936-b8bd-1520ac9992ff
# Trying to extract the image for fb2e1d79-9f64-4936-b8bd-1520ac9992ff
# The Dashboard image for Covid 19 Internal V6_Account Risk.png is extracted
# Dashid : e57ada42-bc18-4882-b091-78affe8bcf1c
# Trying to extract the image for e57ada42-bc18-4882-b091-78affe8bcf1c
# The Dashboard image for Covid 19 Internal V6_GDP Impact.png is extracted
# Dashid : e878ddad-a6a9-4cdb-8048-c626b6a6fa95
# Trying to extract the image for e878ddad-a6a9-4cdb-8048-c626b6a6fa95
# The Dashboard image for Covid 19 Internal V6_Human Impact.png is extracted
# Dashid : 898e42c8-fe0f-4a0c-b340-245b53748849
# Trying to extract the image for 898e42c8-fe0f-4a0c-b340-245b53748849
# The Dashboard image for Covid 19 Internal V6_Booking Sales and Pipeline.png is extracted
# Dashid : b87c4219-f8de-4b21-aa3a-371839950bfc
# Trying to extract the image for b87c4219-f8de-4b21-aa3a-371839950bfc
# The Dashboard image for Covid 19 Internal V6_Geo Industry Risk.png is extracted
# Dashid : 3e543fe5-4727-41d4-9307-8f77494723b9
# Trying to extract the image for 3e543fe5-4727-41d4-9307-8f77494723b9
# The Dashboard image for Covid 19 External V6_Executive Dashboard.png is extracted
# Dashid : ea21261b-802d-4747-8a98-c6246a014e81
# Trying to extract the image for ea21261b-802d-4747-8a98-c6246a014e81
# The Dashboard image for Covid 19 External V6_Account Risk.png is extracted
# Dashid : bad920f4-1e21-4d5b-9a44-bc486dab94be
# Trying to extract the image for bad920f4-1e21-4d5b-9a44-bc486dab94be
# The Dashboard image for Covid 19 External V6_GDP Impact.png is extracted
# Dashid : 102681bd-64ed-4ace-8950-340b9667a599
# Trying to extract the image for 102681bd-64ed-4ace-8950-340b9667a599
# The Dashboard image for Covid 19 External V6_Human Impact.png is extracted
# Dashid : 5cec27d0-ee0f-4de1-ae31-57de22b45daf
# Trying to extract the image for 5cec27d0-ee0f-4de1-ae31-57de22b45daf
# The Dashboard image for Covid 19 External V6_Geo Industry Risk.png is extracted
# Dashid : 2fc43911-d1bd-43d4-9f8c-516137095c93
# Trying to extract the image for 2fc43911-d1bd-43d4-9f8c-516137095c93
# The Dashboard image for Covid 19 External V6_Covid Impact on Employee Predictor.png is extracted
# Dashid : 4a8615cd-25f8-4707-b47b-688177de27e5
# Trying to extract the image for 4a8615cd-25f8-4707-b47b-688177de27e5
# The Dashboard image for Workbook for Spanish Insurance(English)_Dashboard Great Car Company.png is extracted
# Dashid : ee9224c2-0bb2-471d-9ba0-492f4f684048
# Trying to extract the image for ee9224c2-0bb2-471d-9ba0-492f4f684048
# The Dashboard image for Covid 19 Internal V6_Covid FTE Projector.png is extracted
# Dashid : 0e17ec1c-d652-4c46-a471-e37343513902
# Trying to extract the image for 0e17ec1c-d652-4c46-a471-e37343513902
# The Dashboard image for Covid 19 Internal V6_Booking Sales and Pipeline (2).png is extracted
# Dashid : 61be50d6-55f8-41b7-bee8-fee121859c46
# Trying to extract the image for 61be50d6-55f8-41b7-bee8-fee121859c46
# The Dashboard image for Covid 19 Internal V6_Booking Sales and Pipeline (3).png is extracted
# Dashid : ba09f038-ba6c-4a73-92c5-4af3bb29645c
# Trying to extract the image for ba09f038-ba6c-4a73-92c5-4af3bb29645c
# The Dashboard image for ESG Insights_ESG Insights Dashboard.png is extracted
# Dashid : fb2a7e6c-1a36-443a-bbe9-1ce379eccdfe
# Trying to extract the image for fb2a7e6c-1a36-443a-bbe9-1ce379eccdfe
# The Dashboard image for Peek-a-Insights_Gross by Genre.png is extracted
# Dashid : 76d79e4b-06bf-414e-9314-acc1c79eec84
# Trying to extract the image for 76d79e4b-06bf-414e-9314-acc1c79eec84
# The Dashboard image for Peek-a-Insights_Gross by Rating & Runtime.png is extracted
# Dashid : e122d57c-17aa-4670-b184-aa265d12ae7c
# Trying to extract the image for e122d57c-17aa-4670-b184-aa265d12ae7c
# The Dashboard image for Peek-a-Insights_Gross By Certification & Public Poles.png is extracted
# Dashid : c183ebaf-2dd0-4d75-a091-f9a733277b2a
# Trying to extract the image for c183ebaf-2dd0-4d75-a091-f9a733277b2a
# The Dashboard image for Peek-a-Insights_Gross By IMDB Ratings.png is extracted
# Dashid : f2320bbc-1fb8-4715-af99-4da5b3e3062a
# Trying to extract the image for f2320bbc-1fb8-4715-af99-4da5b3e3062a
# The Dashboard image for Invoice_Total Invoice.png is extracted
# Dashid : 1fcf4db5-fe32-4952-b470-111b31034879
# Trying to extract the image for 1fcf4db5-fe32-4952-b470-111b31034879
# The Dashboard image for Invoice_Tax.png is extracted
# Dashid : 22cc7cb5-aa96-41ee-b624-bc8da9e65bce
# Trying to extract the image for 22cc7cb5-aa96-41ee-b624-bc8da9e65bce
# The Dashboard image for Invoice_Gross.png is extracted
# Dashid : d950cdd8-1471-4ae4-8cb5-2b05b79a0ade
# Trying to extract the image for d950cdd8-1471-4ae4-8cb5-2b05b79a0ade
# The Dashboard image for Backtest Asset Allocation Dashboard_Asset Allocation.png is extracted
# Dashid : 38287d99-8f79-4d79-a601-7d74b6ba3039
# Trying to extract the image for 38287d99-8f79-4d79-a601-7d74b6ba3039
# The Dashboard image for Backtest Asset Allocation Dashboard_Portfolio Performance.png is extracted
# Dashid : a9aacc3d-d5fd-4e96-957c-28752966d05d
# Trying to extract the image for a9aacc3d-d5fd-4e96-957c-28752966d05d
# The Dashboard image for Backtest Asset Allocation Dashboard_Portfolio Growth and Returns.png is extracted
# Dashid : 4feb11fd-c36d-4a65-aeec-11ab6ebd151d
# Trying to extract the image for 4feb11fd-c36d-4a65-aeec-11ab6ebd151d
# The Dashboard image for Backtest Asset Allocation Dashboard_Annual Returns and Balance Data.png is extracted
# Dashid : 902a5cd3-f337-4b2f-8a9c-ba4261194ce3
# Trying to extract the image for 902a5cd3-f337-4b2f-8a9c-ba4261194ce3
# The Dashboard image for Backtest Asset Allocation Dashboard_Risk and Return Metrics.png is extracted
# Dashid : db6ea5ed-c199-4e10-a6d1-062ed4ce449a
# Trying to extract the image for db6ea5ed-c199-4e10-a6d1-062ed4ce449a
# The Dashboard image for Backtest Asset Allocation Dashboard_Drawdowns.png is extracted
# Dashid : 34a26b80-9d0e-44c5-8245-f730edefa0db
# Trying to extract the image for 34a26b80-9d0e-44c5-8245-f730edefa0db
# The Dashboard image for Backtest Asset Allocation Dashboard_Portfolio Analysis.png is extracted
# Dashid : 73dc69d9-1dda-49da-9517-aeb5cdca352b
# Trying to extract the image for 73dc69d9-1dda-49da-9517-aeb5cdca352b
# The Dashboard image for Backtest Asset Allocation Dashboard_Rolling Returns Analysis.png is extracted
# Dashid : 8f6f1972-998a-40bf-b618-c146ce7c28ab
# Trying to extract the image for 8f6f1972-998a-40bf-b618-c146ce7c28ab
# The Dashboard image for Backtest Asset Allocation Dashboard_Rolling Returns Trend.png is extracted
# Dashid : 4a6577c2-2728-4a9c-a4b4-98df56376e31
# Trying to extract the image for 4a6577c2-2728-4a9c-a4b4-98df56376e31
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Asset Allocation.png is extracted
# Dashid : a7122bb9-ea8d-48c0-b87d-f1adfed83eb1
# Trying to extract the image for a7122bb9-ea8d-48c0-b87d-f1adfed83eb1
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Portfolio Performance.png is extracted
# Dashid : 98a4f7be-e453-4192-b317-1b935b6215f9
# Trying to extract the image for 98a4f7be-e453-4192-b317-1b935b6215f9
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Portfolio Growth and Returns.png is extracted
# Dashid : 1a283348-c210-479b-ab8f-b9537702a1db
# Trying to extract the image for 1a283348-c210-479b-ab8f-b9537702a1db
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Annual Returns and Balance Data.png is extracted
# Dashid : 76bf1e9e-c6af-4a1d-b58a-1c744f53ab16
# Trying to extract the image for 76bf1e9e-c6af-4a1d-b58a-1c744f53ab16
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Risk and Return Metrics.png is extracted
# Dashid : dbf1b23f-b3a6-43db-8bab-736867ca1474
# Trying to extract the image for dbf1b23f-b3a6-43db-8bab-736867ca1474
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Drawdowns.png is extracted
# Dashid : d9adf09f-7bb4-461a-81ac-e67985cbaeea
# Trying to extract the image for d9adf09f-7bb4-461a-81ac-e67985cbaeea
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Portfolio Analysis.png is extracted
# Dashid : dcf58461-2eeb-4271-8bba-539a059c8d79
# Trying to extract the image for dcf58461-2eeb-4271-8bba-539a059c8d79
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Rolling Returns Analysis.png is extracted
# Dashid : 2aabae70-9e33-4971-8df1-a797fd93a40a
# Trying to extract the image for 2aabae70-9e33-4971-8df1-a797fd93a40a
# The Dashboard image for Backtest Asset Allocation Dashboard v3_Rolling Returns Trend.png is extracted
# Dashid : 75304149-f243-4630-aef9-998aade0a44a
# Trying to extract the image for 75304149-f243-4630-aef9-998aade0a44a
# The Dashboard image for GHG Emission_Dashboard 1.png is extracted
# Dashid : 1c287bae-09c9-4512-9bd5-3d36fbbd2854
# Trying to extract the image for 1c287bae-09c9-4512-9bd5-3d36fbbd2854
# The Dashboard image for dummy_new_Car Track At Port.png is extracted
# Dashid : 7593a9fd-ce66-4253-92d1-b8027cb93a75
# Trying to extract the image for 7593a9fd-ce66-4253-92d1-b8027cb93a75
# The Dashboard image for dummy_new_Car Track At Inland.png is extracted
# Dashid : eab01a97-3521-4f4b-b48a-06c976224efa
# Trying to extract the image for eab01a97-3521-4f4b-b48a-06c976224efa
# The Dashboard image for dummy_new_Mumbai Port_Demographic.png is extracted
# Dashid : c52441d6-fd4d-410d-b6bc-548b054df85b
# Trying to extract the image for c52441d6-fd4d-410d-b6bc-548b054df85b
# The Dashboard image for dummy_new_Chennai Port_Demographic.png is extracted
# Dashid : bc572ef1-3288-4d6c-b1d2-134478c1bb0f
# Trying to extract the image for bc572ef1-3288-4d6c-b1d2-134478c1bb0f
# The Dashboard image for dummy_new_Mumbai Port_Car.png is extracted
# Dashid : 31c28f01-8d9e-4b07-b9bd-140f3cac44bc
# Trying to extract the image for 31c28f01-8d9e-4b07-b9bd-140f3cac44bc
# The Dashboard image for dummy_new_Chennai Port_Car.png is extracted
# Dashid : 5e75578b-19d4-4cc4-b5c9-a30170c35be2
# Trying to extract the image for 5e75578b-19d4-4cc4-b5c9-a30170c35be2
# The Dashboard image for dummy_new_Dealer Analysis.png is extracted
# Dashid : f20b37f1-dc2c-4877-a201-3ca7cab58675
# Trying to extract the image for f20b37f1-dc2c-4877-a201-3ca7cab58675
# The Dashboard image for dummy_new_City Level Analysis.png is extracted
# Dashid : 101cebf1-9d29-42bf-a218-48b2dfcb6140
# Trying to extract the image for 101cebf1-9d29-42bf-a218-48b2dfcb6140
# The Dashboard image for dummy_new_Glossary.png is extracted
# Dashid : fab70a97-45a5-42b2-9d4f-9ed69205c1e9
# Trying to extract the image for fab70a97-45a5-42b2-9d4f-9ed69205c1e9
# The Dashboard image for Peakon FS_Dashboard 1.png is extracted
# Dashid : 28c4798c-a313-4e8f-b415-ebfe16d6e5d0
# Trying to extract the image for 28c4798c-a313-4e8f-b415-ebfe16d6e5d0
# The Dashboard image for Peakon FS_Dashboard 2.png is extracted
# Dashid : b5b2f7f1-84a3-4e2a-899c-a46d0599c937
# Trying to extract the image for b5b2f7f1-84a3-4e2a-899c-a46d0599c937
# The Dashboard image for ts_background_tasks_04.01_TS Background Tasks.png is extracted
# Dashid : ed7971fd-722a-407a-bb0e-9163bc7cbcbc
# Trying to extract the image for ed7971fd-722a-407a-bb0e-9163bc7cbcbc
# The Dashboard image for Recruitment Dashboard_Dashboard.png is extracted
# Dashid : 88aa4c67-c227-4225-bab3-ced5965353fe
# Trying to extract the image for 88aa4c67-c227-4225-bab3-ced5965353fe
# The Dashboard image for Recruitment Dashboard_Dashboard 2.png is extracted
# The dashboards for which the image could not be extracted: []
# The dashboards for which the image that are extracted: ['CMO_Dashboard-WIP_Reach.png', 'CMO_Dashboard-WIP_Promotion Effect.png', 'CMO_Dashboard-WIP_Conversion.png', 'CMO_Dashboard_Dashboard 1.png', 'CMO_Dashboard_Reach.png', 'CMO_Dashboard_Promotion Effect.png', 'CMO_Dashboard_Conversion.png', 'CMO_Dashboard_Content.png', 'Consolidated Cookbook_Comparison of People Metrics.png', 'Consolidated Cookbook_Comparison of Financial Metrics.png', 'Healthcare-Fraud-Detection_Overview.png', 'Healthcare-Fraud-Detection_Digital Healthcare Ecosystem.png', 'Healthcare-Fraud-Detection_Healthcare Insights from Data.png', 'Healthcare-Fraud-Detection_Fraud Claims Dashboard.png', 'HealthCareFraudulentClaims_Anomaly Detection.png', 'Loss Control-Towing_Network-Savings-Dashboard.png', 'Loss Control-Towing_Exceptions-Dashboard.png', 'Loss Control-Towing_Landing-Page-Dashboard.png', 'Workbook for Spanish Insurance v3_Dashboard Great Car Company.png', 'WFH Analytics_Overview.png', 'WFH Analytics_Detailed Insights.png', 'WFH Analytics Draft_Overview.png', 'WFH Analytics Draft_Detailed Insights.png', 'Covid 19 Internal V6_Executive Dashboard.png', 'Covid 19 Internal V6_Account Risk.png', 'Covid 19 Internal V6_GDP Impact.png', 'Covid 19 Internal V6_Human Impact.png', 'Covid 19 Internal V6_Booking Sales and Pipeline.png', 'Covid 19 Internal V6_Geo Industry Risk.png', 'Covid 19 External V6_Executive Dashboard.png', 'Covid 19 External V6_Account Risk.png', 'Covid 19 External V6_GDP Impact.png', 'Covid 19 External V6_Human Impact.png', 'Covid 19 External V6_Geo Industry Risk.png', 'Covid 19 External V6_Covid Impact on Employee Predictor.png', 'Workbook for Spanish Insurance(English)_Dashboard Great Car Company.png', 'Covid 19 Internal V6_Covid FTE Projector.png', 'Covid 19 Internal V6_Booking Sales and Pipeline (2).png', 'Covid 19 Internal V6_Booking Sales and Pipeline (3).png', 'ESG Insights_ESG Insights Dashboard.png', 'Peek-a-Insights_Gross by Genre.png', 'Peek-a-Insights_Gross by Rating & Runtime.png', 'Peek-a-Insights_Gross By Certification & Public Poles.png', 'Peek-a-Insights_Gross By IMDB Ratings.png', 'Invoice_Total Invoice.png', 'Invoice_Tax.png', 'Invoice_Gross.png', 'Backtest Asset Allocation Dashboard_Asset Allocation.png', 'Backtest Asset Allocation Dashboard_Portfolio Performance.png', 'Backtest Asset Allocation Dashboard_Portfolio Growth and Returns.png', 'Backtest Asset Allocation Dashboard_Annual Returns and Balance Data.png', 'Backtest Asset Allocation Dashboard_Risk and Return Metrics.png', 'Backtest Asset Allocation Dashboard_Drawdowns.png', 'Backtest Asset Allocation Dashboard_Portfolio Analysis.png', 'Backtest Asset Allocation Dashboard_Rolling Returns Analysis.png', 'Backtest Asset Allocation Dashboard_Rolling Returns Trend.png', 'Backtest Asset Allocation Dashboard v3_Asset Allocation.png', 'Backtest Asset Allocation Dashboard v3_Portfolio Performance.png', 'Backtest Asset Allocation Dashboard v3_Portfolio Growth and Returns.png', 'Backtest Asset Allocation Dashboard v3_Annual Returns and Balance Data.png', 'Backtest Asset Allocation Dashboard v3_Risk and Return Metrics.png', 'Backtest Asset Allocation Dashboard v3_Drawdowns.png', 'Backtest Asset Allocation Dashboard v3_Portfolio Analysis.png', 'Backtest Asset Allocation Dashboard v3_Rolling Returns Analysis.png', 'Backtest Asset Allocation Dashboard v3_Rolling Returns Trend.png', 'GHG Emission_Dashboard 1.png', 'dummy_new_Car Track At Port.png', 'dummy_new_Car Track At Inland.png', 'dummy_new_Mumbai Port_Demographic.png', 'dummy_new_Chennai Port_Demographic.png', 'dummy_new_Mumbai Port_Car.png', 'dummy_new_Chennai Port_Car.png', 'dummy_new_Dealer Analysis.png', 'dummy_new_City Level Analysis.png', 'dummy_new_Glossary.png', 'Peakon FS_Dashboard 1.png', 'Peakon FS_Dashboard 2.png', 'ts_background_tasks_04.01_TS Background Tasks.png', 'Recruitment Dashboard_Dashboard.png', 'Recruitment Dashboard_Dashboard 2.png']

# %%
conn.sign_out()
# Out:
# <Response [204]>

# %%
def create_view_metadata1(sitename, root_path):
    views_csv = os.path.join(root_path, f'{sitename}_Views.csv')
    workbooks_csv = os.path.join(root_path, f'{sitename}_Workbooks.csv')
    metadata_csv = os.path.join(root_path, f'{sitename}_View_Metadata.csv')
    
    print(f'View : {views_csv} ; Workbook : {workbooks_csv}')
    
    # Load the Views CSV
    views_df = pd.read_csv(views_csv)
    workbooks_df = pd.read_csv(workbooks_csv)
    
    # Filter Views where sheetType is 'view'
    filtered_views = views_df[views_df['sheetType'] == 'view']
    
    # Extract workbook_name and view_name from contentUrl
    filtered_views['workbook_url'] = filtered_views["workbook_name"]
    filtered_views['workbook_name'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[0])
    filtered_views['view_name'] = filtered_views['contentUrl'].apply(lambda x: x.split('/')[-1])
    
    # Drop rows with NaN values in critical columns
    filtered_views = filtered_views.dropna(subset=['view_name', 'workbook_name'])
    
    print(f'Filtered view names: {filtered_views["view_name"].tolist()}')
    print(f'Filtered workbook names: {filtered_views["workbook_name"].tolist()}')
    print(f'Filtered workbook url: {filtered_views["workbook_url"].tolist()}')
    
    
    # Initialize the metadata dataframe
    metadata_df = pd.DataFrame()
    metadata_df['Site name'] = [sitename] * len(filtered_views)
    metadata_df['View name'] = filtered_views['view_name'].values
    metadata_df['Workbook name'] = filtered_views['workbook_name'].values
    metadata_df['Workbook url'] = filtered_views['workbook_url']
    
    # Extract Project name from Workbooks CSV
    project_names = []
    for workbook_name in filtered_views['workbook_name']:
        project_json = workbooks_df[workbooks_df['name'] == workbook_name]['project'].values
        if len(project_json) > 0:
            project_dict = json.loads(project_json[0].replace("'", "\""))  # Ensure correct JSON format
            project_names.append(project_dict['name'])
        else:
            project_names.append('')  # Handle cases where there is no matching workbook name
    
    metadata_df['Project name'] = project_names
    
    # Extract Column names by traversing the file structure
    column_names = []
    for view_name, project_name, workbook_name in zip(metadata_df['View name'], metadata_df['Project name'], metadata_df['Workbook url']):
        if pd.notna(view_name) and pd.notna(project_name) and pd.notna(workbook_name):
            file_path = os.path.join(root_path, project_name, workbook_name, f'{view_name}.csv')
            print(f'Trying to read file: {file_path}')
            if os.path.exists(file_path):
                try:
                    view_data_df = pd.read_csv(file_path)
                    print(f'Columns in {file_path}: {view_data_df.columns.tolist()}')
                    column_names.append(', '.join(view_data_df.columns))
                except Exception as e:
                    print(f'Error reading {file_path}: {e}')
                    column_names.append('')  # Handle cases where the file cannot be read
            else:
                print(f'File does not exist: {file_path}')
                column_names.append('')  # Handle cases where the file does not exist
        else:
            print(f'Invalid data for view: {view_name}, project: {project_name}, workbook: {workbook_name}')
            column_names.append('')  # Handle cases with NaN values
    
    metadata_df['Column name'] = column_names
    
    print(f'Metadata dataframe:\n{metadata_df}')

# %%
create_view_metadata1(sitename, root_path)
